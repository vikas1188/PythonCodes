# %%
#working on a basic bokeh

#importing bokeh

from bokeh.plotting import figure
from bokeh.io import output_file,show

#prepare some data . make sure the dimension is same for X and Y
X=[1,2,3,4,5]
Y=[6,7,8,9,10]

#prepare the output
output_file("Line.html")

#create a figure object
f = figure()

#create line plot
f.line(X,Y)

#write the plot in the figure
show(f)

# %%
#working on a basic bokeh

#importing bokeh

from bokeh.plotting import figure
from bokeh.io import output_file,show
import pandas


df = pandas.read_csv("data.csv")
#prepare some data . make sure the dimension is same for X and Y
X=df["x"]
Y=df["y"]

#prepare the output
output_file("Line1.html")

#create a figure object
f = figure()

#create line plot
f.line(X,Y)

#write the plot in the figure
show(f)

# %%
#working on a basic bokeh

#importing bokeh

from bokeh.plotting import figure
from bokeh.io import output_file,show
import pandas


df = pandas.read_csv("http://pythonhow.com/data/bachelors.csv")
#prepare some data . make sure the dimension is same for X and Y
X=df["Year"]
Y=df["Engineering"]

#prepare the output
output_file("Line_Bachelors_VS_Year.html")

#create a figure object
f = figure()

#create line plot
f.line(X,Y)

#write the plot in the figure
show(f)

# %%
from bokeh.plotting import figure, output_file, show

# output to static HTML file
output_file("circle1.html")

#p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([3,7.5,10], [3,6,9], size=20, color="navy", alpha=0.5)

# show the results
show(p)

# %%
from bokeh.plotting import figure, output_file, show
# output to static HTML file
output_file("triangle.html")

plot = figure(plot_width=300, plot_height=300)
plot.triangle(x=[1, 2, 3], y=[1, 2, 3], size=[10,20,25],
              color="#99D594", line_width=2)

show(plot)

# %%
import pandas
from bokeh.plotting import figure, output_file, show
 
p=figure(plot_width=500,plot_height=400, tools='pan',logo=None)
 
p.title.text="Cool Data"
p.title.text_color="Gray"
p.title.text_font="times"
p.title.text_font_style="bold"
p.xaxis.minor_tick_line_color=None
p.yaxis.minor_tick_line_color=None
p.xaxis.axis_label="Date"
p.yaxis.axis_label="Intensity"    
 
p.line([1,2,3],[4,5,6])
output_file("graph.html")
show(p)

# %%
import pandas
from bokeh.plotting import figure, output_file, show
import pandas


df=pandas.read_excel("http://pythonhow.com/data/verlegenhuken.xlsx",sheet_name=0)
df["Temperature"]=df["Temperature"]/10
df["Pressure"]=df["Pressure"]/10

p=figure(plot_width=500,plot_height=400, tools='pan',logo=None)
 
p.title.text="Cool Data"
p.title.text_color="Gray"
p.title.text_font="times"
p.title.text_font_style="bold"
p.xaxis.minor_tick_line_color=None
p.yaxis.minor_tick_line_color=None
p.xaxis.axis_label="Temperature(C)"
p.yaxis.axis_label="Pressure(hPa)"    
 
p.circle(df["Temperature"],df["Pressure"],size=0.5)
output_file("temprature_distribution.html")
show(p)
